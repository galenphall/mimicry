# %%
import numpy as np
import zarr
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
data = zarr.load("./mimicry_2024-06-18_12-34-53.zarr/")

# %%
s = data['s']
v = data['v']
d = data['d']
r = data['r']

# %%
s_weighted = []
d_mean = []
s_mimic = []
for t in range(len(s)):
    s_t = s[t]
    d_t = d[t]
    v_t = v[t]
    s_weighted += [(s_t[:500].T * v_t).sum(1) / v_t.sum()]
    d_mean += [d_t.mean(0)]
s_weighted = np.array(s_weighted)
d_mean = np.array(d_mean)

# %%
plt.plot(range(len(s)), s.mean(1)[:100])

# %%
plt.plot(range(1, len(v) + 1), v.mean(1))
# plt.xscale('log')

# %%
plt.plot(range(1, 10000), abs(s[1:] - s[:-1]).mean((2,1)))
